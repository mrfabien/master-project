# %%
import xarray as xr
import numpy as np

# %%
path_curnagl = '/Users/fabienaugsburger/Downloads/ERA5_1990-1_convective_available_potential_energy.nc'
path_cds = '/Users/fabienaugsburger/Downloads/CAPE.nc'

ds_curnagl = xr.open_dataset(path_curnagl)
ds_cds = xr.open_dataset(path_cds)

# %%
specific_var = list(ds_cds.variables)[0]
specific_var_curnagl = list(ds_curnagl.variables)[0]

# %%
specific_var = list(ds_cds.variables)[0]

if specific_var == 'longitude':
    specific_var = list(ds_cds.variables)[3]

# %%
# extract variable 

cape_curnagl = ds_curnagl['cape']
cape_cds = ds_cds['cape']

# check if the two datasets are equal

#np.all(cape_curnagl == cape_cds)

cape_curnagl
# Out:
# <xarray.DataArray 'cape' (time: 744, latitude: 721, longitude: 1440)>
# [772450560 values with dtype=float32]
# Coordinates:
#   * latitude   (latitude) float64 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#   * longitude  (longitude) float64 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#   * time       (time) datetime64[ns] 1990-01-01 ... 1990-01-31T23:00:00
# Attributes: (12/14)
#     long_name:                     Convective available potential energy
#     short_name:                    cape
#     units:                         J kg**-1
#     original_format:               WMO GRIB 1 with ECMWF local table
#     ecmwf_local_table:             128
#     ecmwf_parameter:               59
#     ...                            ...
#     grid_specification:            0.25 degree x 0.25 degree from 90N to 90S ...
#     rda_dataset:                   ds633.0
#     rda_dataset_url:               https:/rda.ucar.edu/datasets/ds633.0/
# ...

# %%
# change the data type to float 64 of the cds dataset

cape_cds_lat = cape_cds['latitude'].astype('float64')
cape_cds_lon = cape_cds['longitude'].astype('float64')

# add the latitude and longitude to the cds dataset

cape_cds['latitude'] = cape_cds_lat
cape_cds['longitude'] = cape_cds_lon

# change the coordinates order of the cds dataset such as longitude is the first dimension latitude the second and time the third

#cape_cds = cape_cds.transpose('time', 'latitude', 'longitude')

# %%
cape_cds
# Out:
# <xarray.DataArray 'cape' (time: 744, latitude: 721, longitude: 1440)>
# [772450560 values with dtype=float32]
# Coordinates:
#   * longitude  (longitude) float64 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#   * latitude   (latitude) float64 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#   * time       (time) datetime64[ns] 1990-01-01 ... 1990-01-31T23:00:00
# Attributes:
#     units:      J kg**-1
#     long_name:  Convective available potential energy

# %%
# change the order of the coordinates of the cds dataset

cape_cds = cape_cds.transpose('latitude', 'longitude','time')

cape_cds
# Out:
# <xarray.DataArray 'cape' (latitude: 721, longitude: 1440, time: 744)>
# [772450560 values with dtype=float32]
# Coordinates:
#   * longitude  (longitude) float64 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#   * latitude   (latitude) float64 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#   * time       (time) datetime64[ns] 1990-01-01 ... 1990-01-31T23:00:00
# Attributes:
#     units:      J kg**-1
#     long_name:  Convective available potential energy

# %%
# save as netcdf with the attributs of the cds dataset

cape_cds.to_netcdf('/Users/fabienaugsburger/Downloads/CAPE_cds_v2.nc', mode='w', format='NETCDF4', engine='netcdf4', encoding=None, unlimited_dims=None, compute=True)

# %%
# open the new netcdf file

ds_cds_v2 = xr.open_dataset('/Users/fabienaugsburger/Downloads/CAPE_cds_v2.nc')
ds_cds_v2
# Out:
# <xarray.Dataset>
# Dimensions:    (longitude: 1440, latitude: 721, time: 744)
# Coordinates:
#   * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#   * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#   * time       (time) datetime64[ns] 1990-01-01 ... 1990-01-31T23:00:00
# Data variables:
#     cape       (time, latitude, longitude) float64 ...
